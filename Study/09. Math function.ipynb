# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 이미지 삽입 설명 URL : https://ux.stories.pe.kr/187
# - Paste Image

# %% [markdown]
# # <img src='2024-05-13-15-20-58.png'>

# %%
x = np.linspace(-3, 2, 100)
y = 3 * x**2 + 2

# %%
y
# Out:
# array([29.        , 28.09856137, 27.2124273 , 26.3415978 , 25.48607285,
#        24.64585246, 23.82093664, 23.01132537, 22.21701867, 21.43801653,
#        20.67431895, 19.92592593, 19.19283747, 18.47505357, 17.77257423,
#        17.08539945, 16.41352923, 15.75696358, 15.11570248, 14.48974594,
#        13.87909397, 13.28374656, 12.7037037 , 12.13896541, 11.58953168,
#        11.05540251, 10.5365779 , 10.03305785,  9.54484236,  9.07193144,
#         8.61432507,  8.17202326,  7.74502602,  7.33333333,  6.93694521,
#         6.55586165,  6.19008264,  5.8396082 ,  5.50443832,  5.184573  ,
#         4.88001224,  4.59075605,  4.31680441,  4.05815733,  3.81481481,
#         3.58677686,  3.37404346,  3.17661463,  2.99449036,  2.82767065,
#         2.67615549,  2.5399449 ,  2.41903887,  2.3134374 ,  2.2231405 ,
#         2.14814815,  2.08846036,  2.04407713,  2.01499847,  2.00122436,
#         2.00275482,  2.01958984,  2.05172942,  2.09917355,  2.16192225,
# ...

# %%
import matplotlib.pyplot as mpl
mpl.style.use('seaborn-whitegrid')

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel('$x$', fontsize=20) # $x$ : 수학 기호 x표현
plt.ylabel('$3x^2 +2$', fontsize=20)
plt.show()
# Out:
# /var/folders/0s/8dffxjb55g767y_3df067w080000gn/T/ipykernel_2164/724424159.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-whitegrid')

# %%
x = np.linspace(-3, 2, 100)
y1 = 3 * x**2 + 2
y2 = 3 * (x+1)**2 + 2

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y1, lw=2, ls='dashed', label='$y=3x^2 + 2$')
plt.plot(x, y2, label='$y=3(x+1)^2 +2$')
plt.legend(fontsize=15)
plt.xlabel('$x$', fontsize=20) # $x$ : 수학 기호 x표현
plt.ylabel('$x$', fontsize=20)
plt.show()
